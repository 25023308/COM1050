# %%
#W2A8
do_C=float(input("Nhập nhiệt độ theo độ C: "))
do_F=(9/5*do_C)+32
print(f"{do_C} độ C là {do_F: 2f} Độ F")
# Out:
# Nhập nhiệt độ theo độ C: 36
# 36.0 độ C là  96.800000 Độ F

# %%
#W2A3
a=int(input("Nhập số a: "))
b=int(input("Nhập số b: "))
print(a+b)
print(a-b)
print(a*b)
print(a/b)
# Out:
# Nhập số a: 2
# Nhập số b: 4
# 6
# -2
# 8
# 0.5

# %%
#W2A5
a=int(input("Nhập số a: "))
b=int(input("Nhập số b: "))
print(a**b)
# Out:
# Nhập số a: 5
# Nhập số b: 3
# 125

# %%
#W2A13
a=int(input("Nhập số nguyên dương \a: "))
b=int(input("Nhập số nguyên dương \b: "))
print(a*b)
# Out:
# Nhập số nguyên dương : 2
# : 3
# 6
